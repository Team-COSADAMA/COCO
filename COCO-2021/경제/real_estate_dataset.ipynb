# %% [markdown]
# # 모듈 다운로드

# %%
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt

import platform 

from matplotlib import font_manager, rc 
plt.rcParams['axes.unicode_minus'] = False

if platform.system() == 'Darwin':
    rc('font', family='AppleGothic')
elif platform.system() == 'Windows':
    path = "c:/Windows/Fonts/malgun.ttf"
    font_name = font_manager.FontProperties(fname=path).get_name()
    rc('font', family=font_name)
else:
    print('Unknown system')

import locale

import matplotlib as mpl
# %config InlineBackend.figure_format = 'retina'
import matplotlib.font_manager as fm
fontpath = '/usr/share/fonts/truetype/nanum/NanumBarunGothic.ttf'
font = fm.FontProperties(fname=fontpath, size=9)
plt.rc('font', family='NanumBarunGothic') 
mpl.font_manager._rebuild()

# %% [markdown]
# # 데이터 파일 불러오기

# %%
average_selling_price_raw_data = pd.read_excel('average_selling_price(2012.01-.xlsx', header = 10)
average_unit_selling_price_raw_data = pd.read_excel('average_unit_selling_price(2012.01~.xlsx', header = 10)
median_sellign_price_raw_data = pd.read_excel('median_selling_price(2012.01~.xlsx', header = 10)

# %%
average_selling_price_raw_data
# Out:
#       지 역 Unnamed: 1 Unnamed: 2 2012년 01월 2012년 02월 2012년 03월 2012년 04월  \
# 0      전국        NaN        NaN    241108    240843    240486    239725
# 1     수도권        NaN        NaN    343420    342793    341758    340011
# 2     지방권        NaN        NaN    146377    146448    146718    146870
# 3   6대광역시        NaN        NaN    183130    182995    183058    183044
# 4   5대광역시        NaN        NaN    179831    179754    179954    180017
# 5     9개도        NaN        NaN    188230    188224    188157    187954
# 6     8개도        NaN        NaN    124615    124782    125098    125308
# 7      서울        NaN        NaN    484415    483187    481343    477814
# 8     NaN       강북지역        NaN    386182    385886    384912    383655
# 9     NaN        NaN        도심권    583680    583483    581628    581260
# 10    NaN        NaN        동북권    359451    359226    358370    356535
# 11    NaN        NaN        서북권    357785    357251    356403    356245
# ...

# %% [markdown]
# # 평균매매가 데이터

# %%
# 리스트추출한후 merge해서 행이름으로 만들어줄 예정
index_list = average_selling_price_raw_data['지 역']

# %%
index_list[8:15] = ['강북지역', '강북도심', '강북동북', '강북서북', '강남지역', '강남서남', '강남동남']
index_list[16:23] = ['경기경부1', '경기경부2', '경기서해안', '경기동부1', '경기동부2', '경기경의', '경기경원']
index_list[25:28] = ['부산중부', '부산동부', '부산서부']
print(index_list)
# Out:
# 0        전국
# 1       수도권
# 2       지방권
# 3     6대광역시
# 4     5대광역시
# 5       9개도
# 6       8개도
# 7        서울
# 8      강북지역
# 9      강북도심
# 10     강북동북
# 11     강북서북
# 12     강남지역
# 13     강남서남
# 14     강남동남
# 15       경기
# 16    경기경부1
# 17    경기경부2
# 18    경기서해안
# 19    경기동부1
# 20    경기동부2
# 21     경기경의
# 22     경기경원
# 23       인천
# 24       부산
# 25     부산중부
# 26     부산동부
# 27     부산서부
# 28       대구
# 29       광주
# 30       대전
# 31       울산
# 32       세종
# 33       강원
# 34       충북
# 35       충남
# 36       전북
# 37       전남
# 38       경북
# 39       경남
# 40       제주
# Name: 지 역, dtype: object
# <ipython-input-6-f33deaa26d40>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   index_list[8:15] = ['강북지역', '강북도심', '강북동북', '강북서북', '강남지역', '강남서남', '강남동남']
# ...

# %%
average_selling_price_raw2_data = average_selling_price_raw_data.drop(['지 역', 'Unnamed: 1', 'Unnamed: 2'], axis = 1)

# %%
average_selling_price_raw2_data.insert(0, '지 역', index_list)

# %%
average_selling_price_raw3_data = average_selling_price_raw2_data.set_index('지 역')

# %% [markdown]
# ### 세분화된 평균매매가

# %%
subdivided_average_selling_price = average_selling_price_raw3_data
subdivided_average_selling_price = subdivided_average_selling_price.replace('-', 0)
subdivided_average_selling_price
# Out:
#        2012년 01월  2012년 02월  2012년 03월  2012년 04월  2012년 05월  2012년 06월  \
# 지 역
# 전국        241108     240843     240486     239725     239186     238249
# 수도권       343420     342793     341758     340011     338820     337044
# 지방권       146377     146448     146718     146870     146935     146775
# 6대광역시     183130     182995     183058     183044     182899     182477
# 5대광역시     179831     179754     179954     180017     180036     179707
# 9개도       188230     188224     188157     187954     187658     187118
# 8개도       124615     124782     125098     125308     125403     125353
# 서울        484415     483187     481343     477814     475972     473092
# 강북지역      386182     385886     384912     383655     382589     381440
# 강북도심      583680     583483     581628     581260     580813     579581
# 강북동북      359451     359226     358370     356535     355194     353913
# 강북서북      357785     357251     356403     356245     355603     354850
# ...

# %%
subdivided_average_selling_price.to_csv('subdivided_average_selling_price')

# %% [markdown]
# ### 전국 평균매매가

# %%
average_selling_price = subdivided_average_selling_price.drop(['강남지역', '강북지역', '수도권', '지방권', '6대광역시', '강북도심', '강북동북', '강북서북', '강남서남', '강남동남', '경기경부1', '경기경부2', '경기서해안', '경기동부1', '경기동부2', '경기경의', '경기경원', '부산중부', '부산서부', '부산동부', '5대광역시', '9개도', '8개도'])

# %%
average_selling_price
# Out:
#      2012년 01월  2012년 02월  2012년 03월  2012년 04월  2012년 05월  2012년 06월  \
# 지 역
# 전국      241108     240843     240486     239725     239186     238249
# 서울      484415     483187     481343     477814     475972     473092
# 경기      273865     273625     273043     272286     271462     270263
# 인천      193693     193374     192997     192741     192066     191348
# 부산      195295     194821     194530     194036     193542     192640
# 대구      163724     164236     164924     165526     165797     165887
# 광주      132796     132770     133364     133666     134272     134835
# 대전      197017     196065     195746     195304     194895     193673
# 울산      206601     207684     208612     209701     210619     211212
# 세종           0          0          0          0          0          0
# 강원      115390     115695     115928     116122     116129     116145
# 충북      131107     131254     131611     132070     132427     132563
# ...

# %%
average_selling_price.to_csv('monthly_average_selling_price')

# %% [markdown]
# # 연평균 매매가

# %% [markdown]
# # EDA

# %% [markdown]
# ### 기술통계량

# %%
print(average_selling_price.describe())
# Out:
#            2012년 01월      2012년 02월      2012년 03월      2012년 04월  \
# count      18.000000      18.000000      18.000000      18.000000
# mean   170260.500000  170301.277778  170346.722222  170231.444444
# std    100120.678977   99796.380299   99331.611166   98533.182517
# min         0.000000       0.000000       0.000000       0.000000
# 25%    117983.750000  118245.500000  118524.500000  118763.000000
# 50%    149318.000000  150131.000000  150327.000000  150468.500000
# 75%    196586.500000  195754.000000  195442.000000  194987.000000
# max    484415.000000  483187.000000  481343.000000  477814.000000
#
#            2012년 05월      2012년 06월      2012년 07월      2012년 08월  \
# count      18.000000      18.000000      18.000000      18.000000
# mean   170143.000000  169768.722222  169290.000000  168743.000000
# std     98069.957085   97383.274033   96686.788288   95856.173521
# min         0.000000       0.000000       0.000000       0.000000
# ...

# %%
print(average_selling_price.transpose().describe())
# Out:
# 지 역               전국             서울             경기             인천  \
# count     115.000000     115.000000     115.000000     115.000000
# mean   268520.852174  534651.686957  293517.782609  211174.495652
# std     42117.367392  103715.707901   44982.095081   31669.808301
# min    229072.000000  440592.000000  254253.000000  181728.000000
# 25%    234166.500000  450589.500000  262091.000000  190860.500000
# 50%    247791.000000  473092.000000  272310.000000  197616.000000
# 75%    305016.500000  642641.500000  317967.500000  225868.000000
# max    436557.000000  918808.000000  513774.000000  370726.000000
#
# 지 역               부산             대구             광주             대전  \
# count     115.000000     115.000000     115.000000     115.000000
# mean   221265.043478  235971.313043  181718.226087  226127.400000
# std     34398.848299   52411.552748   42644.260958   42703.919485
# min    187443.000000  163724.000000  132770.000000  188274.000000
# ...

# %% [markdown]
# ### 꺾은선 그래프

# %%
average_selling_price.transpose()

average_selling_price.transpose().plot(figsize = (30, 20), grid = True)
# Out:
# <AxesSubplot:>

# %%
''' 서울지역의 부동산 매매가가 다른지역에 비해 월등히 높다는 것을 알 수 있음
특이한점은 2017년 이후로 모든 지역에서 급격히 오른다는 것을 알 수 있음
주로 대통령 임기?(아마 그 시즌이랑 맞아 떨어짐 - 다시 찾아볼 예졍)가 바뀔때 마다 부동산 가격이 급격히 오르는 것을 알 수 있음

급격하게 오르는 부분 찾아보면 좋을 것 같다

전국적(모든 추세)
2015년 6월 7월 사이
2017년 11월 12월 사이
2018년 12월 2019년 1월사이
2019년 12월 2020년 1월사이

세종시, 제주시 16년 8-9월
세종시 2020년 급격히 오름

서울시 : 17년부터 오름

코로나 이후 찾아보면 좋을 것
'''
# Out:
# ' 서울지역의 부동산 매매가가 다른지역에 비해 월등히 높다는 것을 알 수 있음\n특이한점은 2017년 이후로 모든 지역에서 급격히 오른다는 것을 알 수 있음\n주로 대통령 임기?(아마 그 시즌이랑 맞아 떨어짐 - 다시 찾아볼 예졍)가 바뀔때 마다 부동산 가격이 급격히 오르는 것을 알 수 있음\n\n급격하게 오르는 부분 찾아보면 좋을 것 같다\n\n전국적(모든 추세)\n2015년 6월 7월 사이\n2017년 11월 12월 사이\n2018년 12월 2019년 1월사이\n2019년 12월 2020년 1월사이\n\n세종시, 제주시 16년 8-9월\n세종시 2020년 급격히 오름\n\n서울시 : 17년부터 오름\n\n코로나 이후 찾아보면 좋을 것\n'

# %% [markdown]
# # 크롤링(폭등시점으로부터 전후1달)

# %%
crawldata1 = pd.read_excel('for_title.xlsx')
crawldata1
# Out:
#             뉴스 식별자        일자     언론사        기고자  \
# 0     2.100801e+06  20200229   아시아경제        임주형
# 1     2.100201e+06  20200229   머니투데이     이재은|기자
# 2     2.100311e+06  20200229    서울경제     권혁준 기자
# 3     2.100201e+06  20200229   머니투데이     이소은|기자
# 4     2.100801e+06  20200229   아시아경제        문제원
# ...            ...       ...     ...        ...
# 4925  2.100311e+06  20200127    서울경제     이태규 기자
# 4926  1.100801e+06  20200127    조선일보  세종/정원석 기자
# 4927  2.100601e+06  20200127    한국경제        NaN
# 4928  2.100851e+06  20200127    아주경제        노경조
# 4929  7.101201e+06  20200127  디지털타임스        진현진
#
#                                              제목     통합 분류1      통합 분류2  \
# 0          종말론사무소 "신천지 재산규모 5513억원 중견기업급 자산" 주장    경제>경제일반         NaN
# 1            종말론사무소 "신천지 재산 5000억원, 연 현금흐름 1조원"    경제>경제일반         NaN
# 2                [머니+ 부동산Q&A] 도시민박업 신청 방법과 주의점은     경제>부동산       지역>대전
# 3               "옛날 수색이 아니지"..'10억 클럽' 오른 수색뉴타운     경제>부동산       지역>제주
# ...

# %%
crawldata1
# Out:
#             뉴스 식별자        일자     언론사        기고자  \
# 0     2.100801e+06  20200229   아시아경제        임주형
# 1     2.100201e+06  20200229   머니투데이     이재은|기자
# 2     2.100311e+06  20200229    서울경제     권혁준 기자
# 3     2.100201e+06  20200229   머니투데이     이소은|기자
# 4     2.100801e+06  20200229   아시아경제        문제원
# ...            ...       ...     ...        ...
# 4925  2.100311e+06  20200127    서울경제     이태규 기자
# 4926  1.100801e+06  20200127    조선일보  세종/정원석 기자
# 4927  2.100601e+06  20200127    한국경제        NaN
# 4928  2.100851e+06  20200127    아주경제        노경조
# 4929  7.101201e+06  20200127  디지털타임스        진현진
#
#                                              제목     통합 분류1      통합 분류2  \
# 0          종말론사무소 "신천지 재산규모 5513억원 중견기업급 자산" 주장    경제>경제일반         NaN
# 1            종말론사무소 "신천지 재산 5000억원, 연 현금흐름 1조원"    경제>경제일반         NaN
# 2                [머니+ 부동산Q&A] 도시민박업 신청 방법과 주의점은     경제>부동산       지역>대전
# 3               "옛날 수색이 아니지"..'10억 클럽' 오른 수색뉴타운     경제>부동산       지역>제주
# ...

# %%
crawldata1.drop(['뉴스 식별자', '일자', '언론사', '기고자', '통합 분류1', '통합 분류2', '통합 분류3', '사건/사고 분류1', '사건/사고 분류2', '사건/사고 분류3', '인물', 'URL', '분석제외 여부'], axis = 1, inplace = True)

# %%
# !pip install konlpy
import nltk
from konlpy.tag import Okt

# %%
okt = Okt()

# %%
text = ''

for each_line in crawldata1['키워드']:
    text = text + each_line + '\n'
    
tokens_ko = okt.morphs(text)
tokens_ko
# Out:
# ['종말론',
#  ',',
#  '사무소',
#  ',',
#  '5513억',
#  ',',
#  '신천지',
#  ',',
#  '재산',
#  ',',
#  '규모',
#  ',',
#  '중견',
#  '기업',
#  '급',
#  ',',
#  '자산',
#  ',',
#  '주장',
#  ',',
#  '신천지예수교',
#  '증거',
#  '장막성전',
#  ',',
#  '신천지',
#  ',',
#  '재산',
#  ',',
#  '규모',
#  ',',
#  '5000억',
#  ',',
#  '주장',
#  ',',
#  '제기',
#  ',',
#  '종말론',
#  ',',
#  '유튜브',
#  ',',
#  '채널',
#  ',',
#  '종말',
#  ',',
#  '사무소',
#  ',',
#  '지난달',
#  ',',
#  '경기',
#  ',',
#  '과천시',
#  ',',
#  '정기',
#  '총회',
#  ',',
#  '신천지',
#  ',',
#  '정기',
#  ',',
#  '총회',
#  ',',
#  '녹취록',
#  ',',
#  '토대',
#  ',',
#  '작성',
#  ',',
#  '신천지',
#  ',',
#  '긴급',
#  ',',
#  '보고서',
#  ',',
#  '신천지',
#  ',',
#  '신천지',
#  ',',
#  '재산',
#  ',',
#  '규모',
#  ',',
#  '5513억',
#  ',',
#  '파악',
#  ',',
#  '29일',
#  ',',
#  '종말론',
#  ',',
#  '사무소',
#  ',',
#  '신천지',
#  ',',
#  '회계',
#  ',',
#  '총회',
#  ',',
#  '재정',
#  ',',
#  '재정',
#  ',',
#  '전국',
#  ',',
#  '지',
#  '파',
#  ',',
#  '구별',
#  ',',
#  '처리',
#  ',',
#  '종말론',
#  ',',
#  '사무소',
# ...

# %%
ko = nltk.Text(tokens_ko, name = '2015년 급등시점 본문')
print(len(ko.tokens))
print(len(set(ko.tokens)))
# Out:
# 2360347
# 31786

# %%
stop_words = ['.','을','이','의','를','에',',','가','들','은','는','으로','한','도',
              '수','에서','로','것','그','과','제','입니다','할','하고','적',"'",'하는',
              '합니다','와','에게','고','인',')','?','하여','등','저','있습니다','말','까지',
              '(','1','그리고','다','2','만','딸','했습니다','안','된','못','일','더','위',
              '있는','해','\n','또한','명','하지','..','정말','물','많은','"',
              '중','3','게','너무','A','자','이런','때','되지','위해','에는','없는',
              '및','요','때문','관련','대한','전','라고','되었습니다','하기','나','후','같은','해서',
              '글','되어','주','차','하','내','없이','대해','잘', '‘', 'ㆍ', '’', '\n\n', '[', ']', '-', '='
             , '\n ']

tokens_ko = [each_word for each_word in tokens_ko if each_word not in stop_words]
ko = nltk.Text(tokens_ko, name = '2015년 급등시점 본문')
ko.vocab().most_common(100)
# Out:
# [('부동산', 16522),
#  ('주택', 12224),
#  ('지역', 12134),
#  ('아파트', 10014),
#  ('거래', 8445),
#  ('투자', 7987),
#  ('서울', 7667),
#  ('시장', 7438),
#  ('가격', 7090),
#  ('규제', 6904),
#  ('대출', 6795),
#  ('분양', 6459),
#  ('정부', 6425),
#  ('상승', 5848),
#  ('금융', 5565),
#  ('사업', 5183),
#  ('대상', 5092),
#  ('집값', 4357),
#  ('가구', 4111),
#  ('조사', 4058),
#  ('조정', 3745),
#  ('기준', 3688),
#  ('기업', 3547),
#  ('자금', 3544),
#  ('청약', 3526),
#  ('단지', 3433),
#  ('자산', 3380),
#  ('증가', 3312),
#  ('세', 3266),
#  ('대책', 3227),
#  ('경기', 3166),
#  ('수원', 3140),
#  ('공급', 3045),
#  ('한국', 3023),
#  ('대비', 3001),
#  ('경제', 2996),
#  ('지', 2900),
#  ('전세', 2891),
#  ('대', 2880),
#  ('정책', 2864),
#  ('예정', 2848),
#  ('효과', 2792),
#  ('건설', 2768),
#  ('펀드', 2743),
#  ('신고', 2722),
#  ('계획', 2708),
#  ('수요', 2707),
#  ('매매', 2659),
#  ('원', 2598),
#  ('금리', 2556),
#  ('강남', 2513),
#  ('전망', 2496),
#  ('코로나', 2487),
#  ('상황', 2436),
#  ('하락', 2408),
#  ('전국', 2407),
#  ('은행', 2357),
#  ('장', 2327),
# ...

# %% [markdown]
# # 흠.... 뭐때문인지 모르겠는데요...

# %%
plt.figure(figsize=(15,6))
ko.plot(50)
plt.show()

# %%
#. 워드 클라우드
from wordcloud import WordCloud, STOPWORDS
from PIL import Image
data = dict(ko.vocab().most_common(150))
wordcloud = WordCloud(font_path=r'C:\Users\kangt\AppData\Local\Microsoft\Windows\Fonts\NanumBarunGothic.ttf',
                      relative_scaling = 0.2,
                      background_color='white').generate_from_frequencies(data)
plt.figure(figsize=(8,4))
plt.imshow(wordcloud)
plt.axis("off")
plt.show()
plt.savefig('main.png')

# %%
plt.savefig('main.png', bbox_inches='tight')
